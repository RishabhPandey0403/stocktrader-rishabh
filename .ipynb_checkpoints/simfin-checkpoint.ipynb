# %%
pip install simfin

# %%
import pandas as pd
import numpy as np
# Jupyter widget progress bar
from tqdm import tqdm_notebook as tqdm
# Pickle to import and export the formatted datasets
import _pickle as pickle
# import the data
import simfin as sf

# %%
sf.set_api_key('free')
sf.set_data_dir('~/simfin_data/')

# %%
df = sf.load_income(variant='quarterly', market='us')
df3 = sf.load_balance(variant='quarterly', market='us')
df4 = sf.load_cashflow(variant='quarterly', market='us')

# %%
df4.head()
df4.shape
# Out:
# (71977, 26)

# %%
df3.shape
df.shape
# Out:
# (71977, 26)

# %%
data = pd.merge(df, df3,  how='left', on=['SimFinId','Fiscal Year', 'Fiscal Period','Currency', 'Publish Date','Shares (Basic)','Restated Date','Shares (Diluted)'])
data = pd.merge(data, df4,  how='left', on=['SimFinId','Fiscal Year', 'Fiscal Period','Currency', 'Publish Date','Shares (Basic)','Restated Date','Shares (Diluted)'])
data.shape
# Out:
# (71977, 64)

# %%
data.columns
# Out:
# Index(['SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period', 'Publish Date',
#        'Restated Date', 'Shares (Basic)', 'Shares (Diluted)', 'Revenue',
#        'Cost of Revenue', 'Gross Profit', 'Operating Expenses',
#        'Selling, General & Administrative', 'Research & Development',
#        'Depreciation & Amortization_x', 'Operating Income (Loss)',
#        'Non-Operating Income (Loss)', 'Interest Expense, Net',
#        'Pretax Income (Loss), Adj.', 'Abnormal Gains (Losses)',
#        'Pretax Income (Loss)', 'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income', 'Net Income (Common)',
#        'Cash, Cash Equivalents & Short Term Investments',
#        'Accounts & Notes Receivable', 'Inventories', 'Total Current Assets',
#        'Property, Plant & Equipment, Net',
#        'Long Term Investments & Receivables', 'Other Long Term Assets',
# ...

# %%
df2 = sf.load_shareprices(variant='daily', market='us', index=['Ticker'])
# Out:
# Dataset "us-shareprices-daily" on disk (2 days old).
# - Loading from disk ... Done!

# %%
df2.head()
# Out:
#                     Ticker    Open     Low    High   Close  Adj. Close  \
# SimFinId Date
# 18       2014-03-27   GOOG  568.00  552.92  568.00  558.46      558.46
#          2014-03-28   GOOG  561.20  558.67  566.43  559.99      559.99
#          2014-03-31   GOOG  566.89  556.93  567.00  556.97      556.97
#          2014-04-01   GOOG  558.71  558.71  568.45  567.16      567.16
#          2014-04-02   GOOG  565.11  562.19  604.83  567.00      567.00
#
#                      Dividend  Volume  Shares Outstanding
# SimFinId Date
# 18       2014-03-27       NaN   13100         336050831.0
#          2014-03-28       NaN   41100         336050831.0
#          2014-03-31       NaN   10800         674462000.0
#          2014-04-01       NaN    7900         674462000.0
#          2014-04-02       NaN  146700         674462000.0

# %%
minidata = data[0:500]
minidata.head()
# Out:
#    SimFinId Currency  Fiscal Year Fiscal Period Publish Date Restated Date  \
# 0     45846      USD         2010            Q3   2010-10-06    2011-09-07
# 1     45846      USD         2010            Q4   2010-12-20    2012-12-20
# 2     45846      USD         2011            Q1   2011-03-09    2012-03-05
# 3     45846      USD         2011            Q2   2011-06-07    2012-06-04
# 4     45846      USD         2011            Q3   2011-09-07    2012-09-05
#
#    Shares (Basic)  Shares (Diluted)       Revenue  Cost of Revenue  ...  \
# 0     347000000.0       352000000.0  1.384000e+09     -659000000.0  ...
# 1     344000000.0       356000000.0  1.576000e+09     -742000000.0  ...
# 2     347000000.0       355000000.0  1.519000e+09     -703000000.0  ...
# 3     347000000.0       355000000.0  1.677000e+09     -777000000.0  ...
# 4     348000000.0       357000000.0  1.691000e+09     -799000000.0  ...
#
#    Net Cash from Operating Activities  Change in Fixed Assets & Intangibles  \
# ...

# %%
def grab_offset_close(row, days_offset, recursions):
    if (recursions > 3):
        return None
    try: 
        return df2.loc[row['SimFinId'], (row['Publish Date'] + pd.Timedelta(days=days_offset))]['Close']
    except KeyError:
        return grab_offset_close(row, days_offset -2, recursions+1)

# %%
data['YesterdaySharePrice'] = list(data.apply(grab_offset_close, axis=1,args=(-1,0)))

# %%
minidata['YesterdaySharePrice'] = list(minidata.apply(grab_offset_close, axis=1,args=(-1,0)))
# Out:
# /Users/andrewriordan/anaconda2/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data['NinetyDaySharePrice'] = list(data.apply(grab_offset_close, axis=1,args=(90,0)))

# %%
data['Increase'] = data['NinetyDaySharePrice'] / data['YesterdaySharePrice']

# %%
data.to_csv( "./PredictionData.csv")

# %%
data.head()
# Out:
#    SimFinId Currency  Fiscal Year Fiscal Period Publish Date Restated Date  \
# 0     45846      USD         2010            Q3   2010-10-06    2011-09-07
# 1     45846      USD         2010            Q4   2010-12-20    2012-12-20
# 2     45846      USD         2011            Q1   2011-03-09    2012-03-05
# 3     45846      USD         2011            Q2   2011-06-07    2012-06-04
# 4     45846      USD         2011            Q3   2011-09-07    2012-09-05
#
#    Shares (Basic)  Shares (Diluted)       Revenue  Cost of Revenue  ...  \
# 0     347000000.0       352000000.0  1.384000e+09     -659000000.0  ...
# 1     344000000.0       356000000.0  1.576000e+09     -742000000.0  ...
# 2     347000000.0       355000000.0  1.519000e+09     -703000000.0  ...
# 3     347000000.0       355000000.0  1.677000e+09     -777000000.0  ...
# 4     348000000.0       357000000.0  1.691000e+09     -799000000.0  ...
#
#    Net Cash from Acquisitions & Divestitures  \
# ...

# %%
data2 = data[data.Increase.notnull()]

# %%
data = pd.read_csv('PredictionData.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# 0           0     45846      USD         2010            Q3   2010-10-06
# 1           1     45846      USD         2010            Q4   2010-12-20
# 2           2     45846      USD         2011            Q1   2011-03-09
# 3           3     45846      USD         2011            Q2   2011-06-07
# 4           4     45846      USD         2011            Q3   2011-09-07
#
#   Restated Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 0    2011-09-07     347000000.0       352000000.0  1.384000e+09  ...
# 1    2012-12-20     344000000.0       356000000.0  1.576000e+09  ...
# 2    2012-03-05     347000000.0       355000000.0  1.519000e+09  ...
# 3    2012-06-04     347000000.0       355000000.0  1.677000e+09  ...
# 4    2012-09-05     348000000.0       357000000.0  1.691000e+09  ...
#
#    Net Cash from Acquisitions & Divestitures  \
# 0                              -1.102000e+09
# ...

# %%
data.boxplot(column=['Increase'])

# %%
data.sort_values(by=['Increase'], ascending=False, na_position='last')
# Out:
#        Unnamed: 0  SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# 21501       21501    352819      USD         2016            Q3   2016-11-01
# 64918       64918    692917      USD         2011            Q2   2011-08-15
# 60191       60191    511627      USD         2014            Q3   2014-11-13
# 51515       51515    778232      USD         2016            Q4   2017-04-13
# 37597       37597    155590      USD         2012            Q2   2012-08-13
# ...           ...       ...      ...          ...           ...          ...
# 71894       71894    994625      USD         2017            Q4   2018-03-15
# 71904       71904    994625      USD         2020            Q2   2020-09-04
# 71941       71941    901866      USD         2020            Q2   2020-08-03
# 71962       71962    901704      USD         2020            Q2   2020-08-10
# 71976       71976    171401      USD         2020            Q2   2020-07-28
#
# ...

# %%
data[data['SimFinId'] == 352819]
# Out:
#        Unnamed: 0  SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# 21499       21499    352819      USD         2016            Q1   2016-05-09
# 21500       21500    352819      USD         2016            Q2   2016-08-02
# 21501       21501    352819      USD         2016            Q3   2016-11-01
#
#       Restated Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 21499    2016-05-09             NaN               NaN  1.113000e+09  ...
# 21500    2016-08-02             NaN               NaN  1.115000e+09  ...
# 21501    2016-11-01             NaN               NaN  2.026000e+09  ...
#
#        Net Cash from Acquisitions & Divestitures  \
# 21499                                        NaN
# 21500                              -1.343000e+09
# 21501                               0.000000e+00
#
#        Net Cash from Investing Activities  Dividends Paid  \
# 21499                       -9.500000e+07             NaN
# ...

# %%
df2[df2['SimFinId'] == 352819].
# Out:
#         SimFinId       Date   Open    Low   High  Close  Adj. Close  Dividend  \
# Ticker
# EFH       352819 2013-04-12   0.58   0.53   0.58   0.54        0.54       NaN
# EFH       352819 2013-04-11   0.57   0.53   0.61   0.55        0.55       NaN
# EFH       352819 2013-04-10   0.50   0.50   0.57   0.57        0.57       NaN
# EFH       352819 2013-04-09   0.46   0.45   0.49   0.49        0.49       NaN
# EFH       352819 2013-04-08   0.43   0.43   0.46   0.45        0.45       NaN
# ...          ...        ...    ...    ...    ...    ...         ...       ...
# EFH       352819 2011-02-23   9.70   9.30  10.00   9.90        9.90       NaN
# EFH       352819 2011-02-24   7.65   7.65   7.65   7.65        7.65       NaN
# EFH       352819 2011-02-25   7.84   7.80   7.91   7.88        7.88       NaN
# EFH       352819 2011-02-28  10.20  10.10  10.40  10.30       10.30       NaN
# EFH       352819 2011-02-16   7.55   7.55   7.60   7.60        7.60       NaN
#
# ...

# %%
df2[df2['SimFinId'] == 352819].plot.line(x='Date', y='Close')

# %%
import pandas_bokeh
pandas_bokeh.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
pip install pandas_bokeh
# Out:
# ...
#      |████████████████████████████████| 18.5MB 3.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0MB 3.9MB/s eta 0:00:01
# ...
#   Found existing installation: Pillow 6.2.0
#     Uninstalling Pillow-6.2.0:
#       Successfully uninstalled Pillow-6.2.0
#   Found existing installation: bokeh 1.3.4
#     Uninstalling bokeh-1.3.4:
#       Successfully uninstalled bokeh-1.3.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df2[df2['SimFinId'] == 352819].sort_values(by=['Date'], ascending=True, na_position='last').plot_bokeh(kind='line',x='Date', y='Close')
# Out:
#   <div class="bk-root" id="f857dc2b-f225-45cb-a849-ff1d4bdb339f" data-root-id="1652"></div>
# Figure(id='1652', ...)

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['YesterdaySharePrice','NinetyDaySharePrice','Increase','Currency','Fiscal Year', 'Fiscal Period', 'Publish Date', 'Restated Date'], axis=1)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, data['Increase'], test_size=0.2, random_state=42)

from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-6b8dea539d05> in <module>
#       6
#       7
# ----> 8 reg = LinearRegression().fit(X_train, y_train)
#       9
#      10
#
# ~/anaconda2/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda2/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
X.isna().sum()
dataNotNull = data[['SimFinId','Pretax Income (Loss), Adj.', 'Pretax Income (Loss)','Net Income','Net Income (Common)','YesterdaySharePrice','Increase']].dropna()

# %%
dataNotNull.shape
# Out:
# (71977, 7)

# %%
dataNotNull.head()
# Out:
#    SimFinId  Pretax Income (Loss), Adj.  Pretax Income (Loss)  Net Income  \
# 0     45846                   100000000             227000000   205000000
# 1     45846                   238000000             243000000   292000000
# 2     45846                   198000000             198000000   193000000
# 3     45846                   260000000             260000000   200000000
# 4     45846                   281000000             281000000   330000000
#
#    Net Income (Common)  YesterdaySharePrice  Increase
# 0            205000000                33.04  1.255751
# 1            292000000                40.54  1.059201
# 2            193000000                45.97  1.037633
# 3            200000000                47.06  0.761581
# 4            330000000                33.92  1.090212

# %%
dataNotNull.dropna().head()
# Out:
#    SimFinId  Pretax Income (Loss), Adj.  Pretax Income (Loss)  Net Income  \
# 0     45846                   100000000             227000000   205000000
# 1     45846                   238000000             243000000   292000000
# 2     45846                   198000000             198000000   193000000
# 3     45846                   260000000             260000000   200000000
# 4     45846                   281000000             281000000   330000000
#
#    Net Income (Common)  YesterdaySharePrice  Increase
# 0            205000000                33.04  1.255751
# 1            292000000                40.54  1.059201
# 2            193000000                45.97  1.037633
# 3            200000000                47.06  0.761581
# 4            330000000                33.92  1.090212

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(dataNotNull.drop(columns=['YesterdaySharePrice','Increase'],axis=1), dataNotNull['YesterdaySharePrice'], test_size=0.2)
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_test,y_test)
# Out:
# 0.013019102537129677
